# %% [markdown]
# <a href="https://colab.research.google.com/github/vivivicdjdk/machine/blob/main/9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 순차 데이터와 순환 신경망

# %% [markdown]
# **순차 데이터(sequential data)**
#
# 텍스트나 **시계열 데이터**와 같이 순서에 의미가 있는 데이터
#
# 지금까지 우리가 보았던 데이터는 순서는 상관이 없었음
#
# 순차 데이터를 다룰 때는 이전에 입력한 데이터를 기억하는 기능이 필요

# %% [markdown]
# **피드포워드 신경망(feedforward neural network)**
#
# * 입력 데이터의 흐름이 앞으로만 전달되는 신경망
#
# * 이전 장에서 배웠던 완전 연결 신경망과 합성곱 신경망이 속함

# %% [markdown]
# **순환 신경망(recurrent neural network)**
#
# * 일반적인 완전 연결 신경망과 거의 비슷
#
# * 완전 연결 신경망에 이전 데이터의 처리 흐름을 순환하는 고리 하나를 추가
#
# * 즉, 어떤 샘플을 처리할 때 바로 이전에 사용했던 데이터를 재사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 첫 번째 샘플 A를 처리하고 난 출력이 다시 뉴런으로 들어감
#
# 이 출력에는 A에 대한 출력이 들어있음
#
# 그다음 B를 처리할 때 앞에서 A를 사용해 만든 출력을 함께 사용

# %% [markdown]
# **타음 스텝** 샘플을 처리하는 한 단계
#
# 순환신경망은 이전 타임스텝의 샘플을 기억하지만 타임스텝이 오래될수록 순환되는 정보는 희미해짐
#
# **셀** 한 셀에는 여러 개의 뉴런이 있지만 완전 연결 신경망과 달리 뉴런을 모두 표시하지 않고 하나의 셀로 층을 표현
#
# **은닉 상태** 셀의 출력
